# %% [markdown]
# ## INSTRUCTIONS
#
# Every learner should submit his/her own homework solutions. However, you are allowed to discuss the homework with each other– but everyone must submit his/her own solution; you may not copy someone else’s solution.
#
# The homework consists of two parts:
# 1.	Data manipulation
# 2.	Exploratory Data Analysis
#
# Follow the prompts in the attached jupyter notebook. Download the data and place it in your working directory, or modify the path to upload it to your notebook. Add markdown cells to your analysis to include your solutions, comments, answers. Add as many cells as you need, for easy readability comment when possible.Make sure that you run your whole notebook before saving and sending it to us.
#
# Hopefully this homework will help you develop skills, make you understand the flow of an EDA, get you ready for individual work.
#
# Submission: Send in both a ipynb and a pdf file of your work.
#
# Good luck!

# %% [markdown]
# # Part1: Cleaning, wrangling data

# %% [markdown]
# **Data cleaning focuses on removing inaccurate data from your data set whereas data wrangling focuses on transforming the data's format, typically by converting “raw” data into another format more suitable for use.
# This excersize uses the traffic_cameras file. Your task is to follow prompts to change, modify your data. Try your best!**

# %%
#read in libraries
import numpy as np
from sklearn.datasets import load_iris
from sklearn import preprocessing
import pandas as pd

# %%
# Reading the CSV file
df = pd.read_csv("traffic_cameras.csv")
 
# Printing top 5 rows
df.head()
# Out:
#    Camera ID                              Location Name Camera Status  \
# 0        370   PLEASANT VALLEY RD / NUCKOLS CROSSING RD     TURNED_ON
# 1        379             BARTON SPRINGS RD / KINNEY AVE     TURNED_ON
# 2        404             SPRINGDALE RD / OAK SPRINGS DR     TURNED_ON
# 3        447                 BRAKER LN / STONELAKE BLVD     TURNED_ON
# 4        552              EXPOSITION BLVD / WESTOVER RD     TURNED_ON
#
#   Turn on Date Camera Manufacturer ATD Location ID Landmark  \
# 0    5/24/2018             Advidia    LOC16-003180      NaN
# 1    5/21/2018             Advidia    LOC16-000640      NaN
# 2     6/7/2018             Advidia    LOC16-000800      NaN
# 3     9/9/2016             Advidia    LOC16-003740      NaN
# 4    2/24/2020             Advidia    LOC16-003710      NaN
#
#   Signal Engineer Area Council District         Jurisdiction  ...  \
# 0            SOUTHEAST                2  AUSTIN FULL PURPOSE  ...
# ...

# %% [markdown]
# ### 1. How many rows and columns does your data have?

# %%
### Your code goes here ###
print("Number of rows: " + str(df.shape[0]))
print("Number of columns: " + str(df.shape[1]))
# Out:
# Number of rows: 802
# Number of columns: 28

# %% [markdown]
# ### 2. What can you tell us about the type of variables we have?

# %%
### Your code goes here ###
print(df.dtypes)
# Out:
# Camera ID                         int64
# Location Name                    object
# Camera Status                    object
# Turn on Date                     object
# Camera Manufacturer              object
# ATD Location ID                  object
# Landmark                         object
# Signal Engineer Area             object
# Council District                 object
# Jurisdiction                     object
# Location Type                    object
# Primary St Segment ID           float64
# Cross St Segment ID             float64
# Primary Street Block            float64
# Primary Street                   object
# PRIMARY_ST_AKA                  float64
# Cross Street Block              float64
# Cross Street                     object
# CROSS_ST_AKA                    float64
# COA Intersection ID             float64
# Modified Date                    object
# IP Comm Status                   object
# IP Comm Status Date and Time     object
# ...

# %%
### Your asnwer should go in here ### change the cell to markdown

# %% [markdown]
# ### 3. Delete only the columns that have all null values, name it df1 (nothing else, but null)

# %%
### Your code goes here ###
df1 = df
for column in df1.columns:
    if df1[column].isnull().all():
        del df1[column]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 802 entries, 0 to 801
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Camera ID                     802 non-null    int64
#  1   Location Name                 802 non-null    object
#  2   Camera Status                 802 non-null    object
#  3   Turn on Date                  442 non-null    object
#  4   Camera Manufacturer           646 non-null    object
#  5   ATD Location ID               802 non-null    object
#  6   Landmark                      94 non-null     object
#  7   Signal Engineer Area          799 non-null    object
#  8   Council District              790 non-null    object
#  9   Jurisdiction                  799 non-null    object
#  10  Location Type                 802 non-null    object
#  11  Primary Street Block          800 non-null    float64
# ...

# %% [markdown]
# ### 4. Dropp columns that have (any) null values name it df2

# %%
### Your code goes here ###
df2 = df.dropna(how="any", axis=1)

# %%
df2.info()
df2.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 802 entries, 0 to 801
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Camera ID                     802 non-null    int64
#  1   Location Name                 802 non-null    object
#  2   Camera Status                 802 non-null    object
#  3   ATD Location ID               802 non-null    object
#  4   Location Type                 802 non-null    object
#  5   Modified Date                 802 non-null    object
#  6   IP Comm Status                802 non-null    object
#  7   IP Comm Status Date and Time  802 non-null    object
#  8   Screenshot Address            802 non-null    object
#  9   ID                            802 non-null    object
#  10  Location                      802 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 69.0+ KB
# (802, 11)

# %% [markdown]
# ### 5. Rename column names in df2 so they are more usable (name the new dataframe df3) to the followings: cam_id, loc_name, cam_stat, atd_loc_id, loc_type, date, comm_stat, comm_stat_date, screen_addr, id, location

# %%
### Your code goes here ###
df3 = df2.rename(columns={'Camera ID': 'cam_id', 'Location Name':'loc_name','Camera Status':'cam_stat','ATD Location ID':'atd_loc_id','Location Type':'loc_type','Modified Date':'date','IP Comm Status':'comm_stat','IP Comm Status Date and Time':'comm_stat_date','Screenshot Address':'screen_addr','ID':'id','Location':'location'})

# %%
df3.head()
# Out:
#    cam_id                                   loc_name   cam_stat    atd_loc_id  \
# 0     370   PLEASANT VALLEY RD / NUCKOLS CROSSING RD  TURNED_ON  LOC16-003180
# 1     379             BARTON SPRINGS RD / KINNEY AVE  TURNED_ON  LOC16-000640
# 2     404             SPRINGDALE RD / OAK SPRINGS DR  TURNED_ON  LOC16-000800
# 3     447                 BRAKER LN / STONELAKE BLVD  TURNED_ON  LOC16-003740
# 4     552              EXPOSITION BLVD / WESTOVER RD  TURNED_ON  LOC16-003710
#
#   loc_type                          date comm_stat  \
# 0  ROADWAY  10/28/2021 08:40:00 AM +0000    ONLINE
# 1  ROADWAY  10/29/2021 08:45:00 AM +0000    ONLINE
# 2  ROADWAY  10/29/2021 07:38:00 PM +0000    ONLINE
# 3  ROADWAY  10/29/2021 07:49:00 PM +0000    ONLINE
# 4  ROADWAY  10/29/2021 07:47:00 PM +0000    ONLINE
#
#                  comm_stat_date                                   screen_addr  \
# 0  10/28/2021 08:30:00 AM +0000  https://cctv.austinmobility.io/image/370.jpg
# ...

# %% [markdown]
# ### 6. Split "date" column into two  new columns within df3 ('Dates' and 'Time') /modify df3 data/

# %%
### Your code goes here ###
df3[['Dates', 'Time']] = df3["date"].apply(lambda x: pd.Series(str(x).split(" ", 1)))
del df3['date']

# %%
df3.head()
# Out:
#    cam_id                                   loc_name   cam_stat    atd_loc_id  \
# 0     370   PLEASANT VALLEY RD / NUCKOLS CROSSING RD  TURNED_ON  LOC16-003180
# 1     379             BARTON SPRINGS RD / KINNEY AVE  TURNED_ON  LOC16-000640
# 2     404             SPRINGDALE RD / OAK SPRINGS DR  TURNED_ON  LOC16-000800
# 3     447                 BRAKER LN / STONELAKE BLVD  TURNED_ON  LOC16-003740
# 4     552              EXPOSITION BLVD / WESTOVER RD  TURNED_ON  LOC16-003710
#
#   loc_type comm_stat                comm_stat_date  \
# 0  ROADWAY    ONLINE  10/28/2021 08:30:00 AM +0000
# 1  ROADWAY    ONLINE  10/29/2021 08:35:00 AM +0000
# 2  ROADWAY    ONLINE  10/28/2021 08:35:00 AM +0000
# 3  ROADWAY    ONLINE  10/23/2021 08:35:00 AM +0000
# 4  ROADWAY    ONLINE  10/20/2021 08:35:00 AM +0000
#
#                                     screen_addr                        id  \
# 0  https://cctv.austinmobility.io/image/370.jpg  591a10a020eacf2d16669b94
# ...

# %% [markdown]
# ### 7. Split atd_loc into two new columns 'Loc' and 'code' within df3

# %%
### Your code goes here ###
df3[['Loc', 'code']] = df3["atd_loc_id"].apply(lambda x: pd.Series(str(x).split("-", 1)))
del df3['atd_loc_id']

# %%
df3.head()
# Out:
#    cam_id                                   loc_name   cam_stat loc_type  \
# 0     370   PLEASANT VALLEY RD / NUCKOLS CROSSING RD  TURNED_ON  ROADWAY
# 1     379             BARTON SPRINGS RD / KINNEY AVE  TURNED_ON  ROADWAY
# 2     404             SPRINGDALE RD / OAK SPRINGS DR  TURNED_ON  ROADWAY
# 3     447                 BRAKER LN / STONELAKE BLVD  TURNED_ON  ROADWAY
# 4     552              EXPOSITION BLVD / WESTOVER RD  TURNED_ON  ROADWAY
#
#   comm_stat                comm_stat_date  \
# 0    ONLINE  10/28/2021 08:30:00 AM +0000
# 1    ONLINE  10/29/2021 08:35:00 AM +0000
# 2    ONLINE  10/28/2021 08:35:00 AM +0000
# 3    ONLINE  10/23/2021 08:35:00 AM +0000
# 4    ONLINE  10/20/2021 08:35:00 AM +0000
#
#                                     screen_addr                        id  \
# 0  https://cctv.austinmobility.io/image/370.jpg  591a10a020eacf2d16669b94
# 1  https://cctv.austinmobility.io/image/379.jpg  591a10a020eacf2d16669ba6
# ...

# %% [markdown]
# ### 8. What are the unique values in loc_type?

# %%
### Your code goes here ###
uniques = df3['loc_type'].unique()
print(uniques)
# Out:
# ['ROADWAY' 'BUILDING']

# %% [markdown]
# ### 9. Replace 'ROADWAY' to '0',  'BUILDING' to '1' in the loc_type column within df3

# %%
### Your code goes here ###
df3.loc[df3['loc_type']=='ROADWAY','loc_type'] = '0'
df3.loc[df3['loc_type']=='BUILDING','loc_type'] = '1'

# %%
df3.head()
# Out:
#    cam_id                                   loc_name   cam_stat loc_type  \
# 0     370   PLEASANT VALLEY RD / NUCKOLS CROSSING RD  TURNED_ON        0
# 1     379             BARTON SPRINGS RD / KINNEY AVE  TURNED_ON        0
# 2     404             SPRINGDALE RD / OAK SPRINGS DR  TURNED_ON        0
# 3     447                 BRAKER LN / STONELAKE BLVD  TURNED_ON        0
# 4     552              EXPOSITION BLVD / WESTOVER RD  TURNED_ON        0
#
#   comm_stat                comm_stat_date  \
# 0    ONLINE  10/28/2021 08:30:00 AM +0000
# 1    ONLINE  10/29/2021 08:35:00 AM +0000
# 2    ONLINE  10/28/2021 08:35:00 AM +0000
# 3    ONLINE  10/23/2021 08:35:00 AM +0000
# 4    ONLINE  10/20/2021 08:35:00 AM +0000
#
#                                     screen_addr                        id  \
# 0  https://cctv.austinmobility.io/image/370.jpg  591a10a020eacf2d16669b94
# 1  https://cctv.austinmobility.io/image/379.jpg  591a10a020eacf2d16669ba6
# ...

# %%
df3.loc_type.unique()
# Out:
# array(['0', '1'], dtype=object)

# %% [markdown]
# ### 10. Split on on '/' the loc_name column into two new variables 'corner1', 'corner2'

# %%
### Your code goes here ###
df3[['corner1', 'corner2']] = df3["loc_name"].apply(lambda x: pd.Series(str(x).split("/", 1)))
del df3['loc_name']

# %%
df3.head()
# Out:
#    cam_id   cam_stat loc_type comm_stat                comm_stat_date  \
# 0     370  TURNED_ON        0    ONLINE  10/28/2021 08:30:00 AM +0000
# 1     379  TURNED_ON        0    ONLINE  10/29/2021 08:35:00 AM +0000
# 2     404  TURNED_ON        0    ONLINE  10/28/2021 08:35:00 AM +0000
# 3     447  TURNED_ON        0    ONLINE  10/23/2021 08:35:00 AM +0000
# 4     552  TURNED_ON        0    ONLINE  10/20/2021 08:35:00 AM +0000
#
#                                     screen_addr                        id  \
# 0  https://cctv.austinmobility.io/image/370.jpg  591a10a020eacf2d16669b94
# 1  https://cctv.austinmobility.io/image/379.jpg  591a10a020eacf2d16669ba6
# 2  https://cctv.austinmobility.io/image/404.jpg  591a10a120eacf2d16669bd8
# 3  https://cctv.austinmobility.io/image/447.jpg  591a10a320eacf2d16669c2e
# 4  https://cctv.austinmobility.io/image/552.jpg  5aa6bb0121cbcf4b8b767294
#
#                          location       Dates               Time    Loc  \
# ...

# %% [markdown]
# # Part2: Exploratory Data Analysis (EDA)

# %% [markdown]
# Exploratory Data Analysis refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.
#
# Follow the lecture notes for ideas of how to perform EDA on your dataset. For help, here are the steps we talked about:
#
# ***Steps in EDA***:
# 1. Provide descriptions of your sample and features
# 2. Check for missing data
# 3. Identify the shape of your data
# 4. Identify significant correlations
# 5. Spot/deal with outliers in the dataset
#
# These steps are a guidline. Try different things and share your insights about the dataset.
#
# **Don't forget to add "markdown" cells to include your findings or to explain what you are doing**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading the CSV file
df_fish = pd.read_csv("Fish.csv")
 
# Printing top 5 rows
df_fish.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
#1. Provide descriptions of your sample and features
#Find row and columns
print("Rows/Observations: " + str(df_fish.shape[0]))
print("Columns/Features: " + str(df_fish.shape[1]))
print(df_fish.info())

#Check how many variables are categorical, rest are likely numeric
categorical_fish = 0
for i in df_fish.dtypes:
    if i == object:
        categorical_fish += 1
print("The data frame has " + str(categorical_fish) + " features that are categorical")

#print quick description
df_fish.describe()
# Out:
# Rows/Observations: 159
# Columns/Features: 7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB
# None
# The data frame has 1 features that are categorical
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# ...

# %%
#2 Check for missing values
missing_values = False
for i in df_fish.isnull().sum():
    if i != 0:
        print("There are missing values")
        missing_values = True
if(not missing_values):
    print("There are no missing values")

print(df_fish.isnull().sum())
print("\n\n")
print(df_fish.value_counts("Species"))
print("We can see our data is not balanced, since there are different amounts of each species of fish")
# Out:
# There are no missing values
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64
#
#
#
# Species
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# dtype: int64
# We can see our data is not balanced, since there are different amounts of each species of fish

# %%
#3 Find shape of data
sns.countplot(x='Species', data=df_fish)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
#From the countplot above, we can see our data consists mainly of the species Perch, and little Whitefish.
#This will affect are conclusion in the future

# %%
sns.scatterplot(data=df_fish, x="Width", y="Height", hue='Species')
# Out:
# <Axes: xlabel='Width', ylabel='Height'>

# %%
#Here, we can see the type of species has a relationship with the fishes size, 
#since many points of the same species are grouped together

#Species Bream Seems on average to have the highest height and width, while smelts are 
#smallest in both. 
#The others seem to lie in the middle, however their width seems to vary.

# %%
sns.stripplot(y ='Length1', x = 'Species', data = df_fish)
# Out:
# <Axes: xlabel='Species', ylabel='Length1'>

# %%
#Here, we see Smelt has the smallest length1, while Pike has some with the highest.
#Perch seems to be in betwen 10-40, which is a large variance, however there are more observations for it 
#compared to the others.

# %%
sns.stripplot(y ='Length2', x = 'Species', data = df_fish)
# Out:
# <Axes: xlabel='Species', ylabel='Length2'>

# %%
#Plot of Length2 seems similar to plot of Length1

# %%
sns.stripplot(y ='Length3', x = 'Species', data = df_fish)
# Out:
# <Axes: xlabel='Species', ylabel='Length3'>

# %%
#Same for length 3, except now Pikes reach up to 70 instead of 60 units.

# %%
sns.histplot(x='Length1', data=df_fish, hue='Species', kde=True)
# Out:
# <Axes: xlabel='Length1', ylabel='Count'>

# %%
sns.histplot(x='Length2', data=df_fish, hue='Species', kde=True)
# Out:
# <Axes: xlabel='Length2', ylabel='Count'>

# %%
sns.histplot(x='Length3', data=df_fish, hue='Species', kde=True)
# Out:
# <Axes: xlabel='Length3', ylabel='Count'>

# %%
#For the 3 lengthsm, we can see Smelt, Bream, and Pike tend to skew away from the other species,
#While Roach,Parkki, and Perch, and Whitefish tend to overlap

# %%
#4 Identify Significant Correlation
df_fish.corr(method="pearson")
# Out:
# C:\Users\gamer\AppData\Local\Temp\ipykernel_22120\1020334001.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_fish.corr(method="pearson")
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Length1  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Length2  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Length3  0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height   0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width    0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %%
#There appears to be significant correlations between the lengths, and some correlation between Width and each of the lengths

# %%
#5 Detect and Handle Outliers
sns.boxplot(x="Species", y="Length1", data=df_fish)
# Out:
# <Axes: xlabel='Species', ylabel='Length1'>

# %%
sns.boxplot(x="Species", y="Length2", data=df_fish)
# Out:
# <Axes: xlabel='Species', ylabel='Length2'>

# %%
sns.boxplot(x="Species", y="Length3", data=df_fish)
# Out:
# <Axes: xlabel='Species', ylabel='Length3'>

# %%
#Here we see when it comes to the lengths of the fish, Roach and Smelt both have outliers within their species. 
#Bream also has outliers within its species when it comes to Length1

#It is possible the outliers were fed more than other fish, or grew up in different environments. 
#There is also the possibility that there were errors made when the data was taken.

# %%
sns.boxplot(x="Species", y="Height", data=df_fish)
# Out:
# <Axes: xlabel='Species', ylabel='Height'>

# %%
sns.boxplot(x="Species", y="Width", data=df_fish)
# Out:
# <Axes: xlabel='Species', ylabel='Width'>

# %%
#When looking at height and width of fish with their species, we see
#its similar to the lengths, where Roach and Smelt both have outliers.
#However Bream appears to have none.

# %%
sns.boxplot(y="Length1", data=df_fish)
# Out:
# <Axes: ylabel='Length1'>

# %%
sns.boxplot(y="Length2", data=df_fish)
# Out:
# <Axes: ylabel='Length2'>

# %%
sns.boxplot(y="Length3", data=df_fish)
# Out:
# <Axes: ylabel='Length3'>

# %%
sns.boxplot(y="Height", data=df_fish)
# Out:
# <Axes: ylabel='Height'>

# %%
sns.boxplot(y="Width", data=df_fish)
# Out:
# <Axes: ylabel='Width'>

# %%
#When comparing the lengths between all of the fish, we can see some outliers at all of the lengths
#When just comparing height and width of all fish, we can see no outliers

# %%
#Remove outliers between all species of fish

#Find quartiles of data
Q1 = df_fish['Length1'].quantile(0.25)
Q3 = df_fish['Length1'].quantile(0.75)
print("Q1 = " + str(Q1))
print("Q3 = " + str(Q3))

IQR = Q3-Q1
print("IQR = " + str(IQR))

u_fence = Q3 + (1.5 * IQR)
print("Upper fence = " + str(u_fence))
# Out:
# Q1 = 19.05
# Q3 = 32.7
# IQR = 13.650000000000002
# Upper fence = 53.175000000000004

# %%
#Find outliers above upper fence
df_fish_filtered = df_fish[df_fish['Length1'] >= u_fence]
sns.boxplot(y="Length1", data=df_fish_filtered)
# Out:
# <Axes: ylabel='Length1'>
